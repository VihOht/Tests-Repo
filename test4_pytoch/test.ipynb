# %%
from llm import KNN, LinearRegression
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from llm import KNN, LinearRegression, Models0
#       2 from sklearn import datasets
#       3 from sklearn.model_selection import train_test_split
#
# ImportError: cannot import name 'Models0' from 'llm' (/home/prismoht/Desktop/diretorys/public/codes/tests/test4_pytoch/llm.py)

# %%
X, y = datasets.make_regression(n_samples=100, n_features=1, noise=20, random_state=1234)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

plt.scatter(X_train[:,0], y_train, color="b", marker='o', s=30)



model_1 = LinearRegression()
model_1.fit(X_train, y_train)
predictions = model_1.predict(X_test)

def r2_score(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    ss_res = np.sum((y_true - y_pred) ** 2)
    ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    return r2

print(f"R^2 Score: {r2_score(y_test, predictions)}")

plt.scatter(X_test[:,0], predictions, color="r", marker="x")
plt.show()
# Out:
# Loss: 6577.254183726365
# Loss: 315.5608844117414
# Loss: 304.0357940896298
# Loss: 304.0135638718668
# Loss: 304.0135206682342
# R^2 Score: 0.9726420500608135

# %%
from llm import Models0


np.random.seed(1234)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 from llm import LinearF
#       2 models_0 = Models0()
#       4 np.random.seed(1234)
#
# ImportError: cannot import name 'LinearF' from 'llm' (/home/prismoht/Desktop/diretorys/public/codes/tests/test4_pytoch/llm.py)
