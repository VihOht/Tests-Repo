# %%
from pysus import CNES
cnes = CNES()
cnes.groups
# Out:
# {'DC': 'Dados Complementares',
#  'EE': 'Estabelecimento de Ensino',
#  'EF': 'Estabelecimento Filantrópico',
#  'EP': 'Equipes',
#  'EQ': 'Equipamentos',
#  'GM': 'Gestão e Metas',
#  'HB': 'Habilitação',
#  'IN': 'Incentivos',
#  'LT': 'Leitos',
#  'PF': 'Profissional',
#  'RC': 'Regra Contratual',
#  'SR': 'Serviço Especializado',
#  'ST': 'Estabelecimentos'}

# %%
from pysus import CNES
import pandas as pd

cnes.load("ST")
cnes.content

files = cnes.get_files("IN", year=2024)
paquets = cnes.download(files, "data/cnes")
df = pd.concat([paquet.to_dataframe() for paquet in paquets], ignore_index=True)
df.head(100)
# Out:
# INDF2411.parquet: : 30.0kB [19:41, 25.4B/s]
# INAM0910.parquet: : 30.0kB [06:13, 80.4B/s]
#
#
# /home/prismoht/Desktop/diretorys/public/codes/tests/test6_pysus/.venv/lib/python3.13/site-packages/tqdm/std.py:533: TqdmWarning: clamping frac to range [0, 1]
#   full_bar = Bar(frac,
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
df["CNES"].nunique()
# Out:
# 9447
